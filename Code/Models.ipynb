# %%
import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xgb
import openpyxl
import seaborn as sns
import numpy as np
from jupyterlab.extensions.pypi import xmlrpc_transport_override
from sklearn.metrics import accuracy_score,recall_score,f1_score,precision_score, roc_auc_score,balanced_accuracy_score,roc_curve, auc,confusion_matrix
from sklearn.svm import SVC
from sklearn.impute import SimpleImputer
import xgboost as xgb
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
import optuna
import warnings
from pandas.errors import PerformanceWarning
from sklearn.mixture import GaussianMixture
from sklearn.linear_model import LogisticRegression
import statsmodels.api as sm
import captum.attr as IntegratedGradients
# Out:
# Caching the list of root modules, please wait!
# (This will only be done once - type '%rehashx' to reset cache!)

# %%
warnings.simplefilter("ignore", PerformanceWarning) #настройка для игнорирования предупреждений о производительности при работе с большими DataFrame
optuna.logging.set_verbosity(optuna.logging.WARNING)
ntrials = 0

# %% [markdown]
# # Prediction for 1 day

# %%
file_path = '/Users/vladislav/Desktop/Данные/predictions_for_1_days.xlsx'
data = pd.read_excel(file_path,index_col='TRADEDATE')
sifts = range(1,30)

for j in (data.drop('crisis',axis=1)).columns:
    data[j] = data[j].pct_change(fill_method=None)
data_copy = data.copy()
for sh in sifts:
    for j in (data_copy.drop('crisis',axis=1)).columns:
        data[f'{j}_lag_{sh}'] = data[j].shift(sh)
imputer = SimpleImputer(strategy='median')
train = data.iloc[:int(len(data)*0.6),:]
test = data.iloc[int(len(data)*0.6):,:]
x_train = train.drop('crisis',axis=1)
y_train = train['crisis']
x_test = test.drop('crisis',axis=1)
y_test = test['crisis']
x_train = imputer.fit_transform(x_train)
x_test = imputer.transform(x_test)

# %% [markdown]
# # XGBoost

# %%
scale_pos_weight = (
    (y_train == 0).sum() /
    (y_train == 1).sum()
)
dtrain = xgb.DMatrix(x_train, label=y_train)
dtest = xgb.DMatrix(x_test, label=y_test)

def objective(trial):

    params = {
        'objective': 'binary:logistic',
        'eval_metric': 'auc',
        'max_depth': trial.suggest_int(
            'max_depth',
            2,
            8
        ),
        'learning_rate': trial.suggest_float(
            'learning_rate',
            0.005,
            0.1,
            log=True
        ),
        'subsample': trial.suggest_float(
            'subsample',
            0.5,
            1.0
        ),

        'colsample_bytree': trial.suggest_float(
            'colsample_bytree',
            0.5,
            1.0
        ),
        'lambda': trial.suggest_float(
            'lambda',
            1e-3,
            10,
            log=True
        ),

        'alpha': trial.suggest_float(
            'alpha',
            1e-3,
            10,
            log=True
        ),
        'gamma': trial.suggest_float(
            'gamma',
            0,
            5
        ),
        'scale_pos_weight': scale_pos_weight,
        'seed': 42
    }
    xgb_model = xgb.train(params,dtrain=dtrain,evals=[(dtrain,'train'),(dtest,'test')],
                          num_boost_round=3000, early_stopping_rounds=50,verbose_eval=False)
    y_prob = xgb_model.predict(dtest)
    auc = roc_auc_score(
        y_test,
        y_prob
    )
    return auc

study = optuna.create_study(
    direction='maximize',storage='sqlite:///xgboost_for_1day_study.db',
    load_if_exists=True,
    study_name='xgboost_for_1day_study'
)

study.optimize(
    objective,
    n_trials=ntrials,
    show_progress_bar=True
)
study = optuna.load_study(storage='sqlite:///xgboost_for_1day_study.db',study_name='xgboost_for_1day_study')
params = {'objective': 'binary:logistic',
        'eval_metric': 'auc',
          'seed': 42}
params.update(study.best_params)
model_xgb = xgb.train(
    params,
    dtrain=dtrain,
    evals=[(dtrain,'train'),(dtest,'test')],
    num_boost_round=3000,
    early_stopping_rounds=100,
    verbose_eval=False
)
y_prob = model_xgb.predict(dtest)
threshold = 0.5
y_pred = (
    y_prob > threshold
).astype(int)
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, y_pred))
print("Precision",precision_score(
        y_test,
        y_pred,
        zero_division=0))
print(
    "Recall",
    recall_score(
        y_test,
        y_pred,
        zero_division=0))
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
Accuracy = []
Recall = []
Per = []
Tr = []
F1 = []
for t in np.arange(0,1,0.05):
    y_prob = model_xgb.predict(dtest)
    y_pred = (
    y_prob > t
).astype(int)
    Accuracy.append(accuracy_score(y_test, y_pred))
    Recall.append(recall_score(y_test, y_pred, zero_division=0))
    Per.append(precision_score(y_test, y_pred, zero_division=0))
    F1.append(f1_score(y_test, y_pred, zero_division=0))
    Tr.append(t)
plt.figure()
sns.lineplot(x = Tr,y = Accuracy,label = 'Accuracy')
sns.lineplot(x = Tr,y = Recall,label = 'Recall')
sns.lineplot(x = Tr,y = Per, label = 'Precision')
sns.lineplot(x = Tr,y = F1, label = 'F1')
# Out:
# AUC 0.8170338868497395
# Accuracy 0.8035495716034272
# Precision 0.6882352941176471
# Recall 0.3038961038961039
# F1 0.42162162162162165
# <Axes: >

# %% [markdown]
# # SVM

# %%
def objective(trial):
    params = {'kernel':trial.suggest_categorical('kernel', ['poly','rbf'])}
    if params['kernel'] == 'poly':
        params['degree'] = trial.suggest_int('degree', 2, 5)
    elif params['kernel'] == 'rbf':
        params['gamma'] = trial.suggest_float('gamma', 1e-3, 4,)
    class_weight = {0:(y_train == 0).sum(),
                1:(y_train == 1).sum()}
    svc_model = SVC(kernel='rbf',gamma=3,probability=True,class_weight=class_weight)
    svc_model.fit(x_train,y_train)
    y_pred = svc_model.predict_proba(x_test)[:, 1]
    auc = roc_auc_score(y_test, y_pred)
    return auc

study = optuna.create_study(
    direction='maximize',storage='sqlite:///svc_for_1day_study.db',
    load_if_exists=True,
    study_name='svc_for_1day_study'
)           

study.optimize(
    objective,
    n_trials=ntrials,
    show_progress_bar=True
)
class_weight = {0:(y_train == 0).sum(),
                1:(y_train == 1).sum()}
study = optuna.load_study(storage='sqlite:///svc_for_1day_study.db',study_name='svc_for_1day_study')
best_params = study.best_params
svc_model = SVC(kernel='rbf',probability=True,class_weight=class_weight)
svc_model.set_params(**best_params)
svc_model.fit(x_train,y_train)
y_prob = svc_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test,
        (y_prob > 0.5).astype(int),
        zero_division=0))
print(    "Recall",
    recall_score(
        y_test,
        (y_prob > 0.5).astype(int),
        zero_division=0))
print("F1",
    f1_score(
        y_test,
        (y_prob > 0.5).astype(int),
        zero_division=0))
Accuracy = []
Recall = []
Per = []
Tr = []
F1 = []
for t in np.arange(0,1,0.05):
    y_prob = svc_model.predict_proba(x_test)[:, 1]
    y_pred = (
    y_prob > t
).astype(int)
    Accuracy.append(accuracy_score(y_test, y_pred))
    Recall.append(recall_score(y_test, y_pred, zero_division=0))
    Per.append(precision_score(y_test, y_pred, zero_division=0))
    F1.append(f1_score(y_test, y_pred, zero_division=0))
    Tr.append(t)
plt.figure()
sns.lineplot(x = Tr,y = Accuracy,label = 'Accuracy')
sns.lineplot(x = Tr,y = Recall,label = 'Recall')
sns.lineplot(x = Tr,y = Per, label = 'Precision')
sns.lineplot(x = Tr,y = F1, label = 'F1')
# Out:
# AUC 0.552624957108544
# Accuracy 0.7643818849449204
# Precision 0.0
# Recall 0.0
# F1 0.0
# <Axes: >

# %% [markdown]
# # AdaBoost

# %%
adaboost_model = AdaBoostClassifier(
    estimator=DecisionTreeClassifier(max_depth=10,class_weight={0: np.sum(y_train == 0), 1: np.sum(y_train == 1)}),
    n_estimators=100,
    learning_rate=0.1,
    random_state=42
)
adaboost_model.fit(x_train, y_train)
y_prob = adaboost_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),
        zero_division=0))
print( "Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.7844446986160356
# Accuracy 0.795593635250918
# Precision 0.6976744186046512
# Recall 0.23376623376623376
# F1 0.0

# %% [markdown]
# # RF

# %%
rf_model = RandomForestClassifier(
    n_estimators=300,
    max_depth=10,
    random_state=42,
    class_weight={0: np.sum(y_train == 0), 1: np.sum(y_train == 1)}
)
rf_model.fit(x_train, y_train)
y_prob = rf_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),     
    zero_division=0))
print( "Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))  
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.7438220706435279
# Accuracy 0.791921664626683
# Precision 0.7368421052631579
# Recall 0.18181818181818182
# F1 0.0

# %% [markdown]
# # EM

# %%
em_model = GaussianMixture(n_components=2, random_state=42)
em_model.fit(x_train,y_train)
y_prob = em_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),
        zero_division=0))
print( "Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.5077880486207148
# Accuracy 0.5177478580171359
# Precision 0.24461343472750316
# Recall 0.5012987012987012
# F1 0.0
# F1 0.0

# %% [markdown]
# # Logit

# %%
logit_model = LogisticRegression(class_weight={0: np.sum(y_train == 0), 1: np.sum(y_train == 1)}, max_iter=1000)
logit_model.fit(x_train, y_train)
y_prob = logit_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),
        zero_division=0))
print("Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))   
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.7433396067503354
# Accuracy 0.784577723378213
# Precision 0.5812807881773399
# Recall 0.3064935064935065
# F1 0.0

# %% [markdown]
# # Roc-Auc

# %%
study = optuna.load_study(storage='sqlite:///xgboost_for_1day_study.db',study_name='xgboost_for_1day_study')
params = {'objective': 'binary:logistic',
        'eval_metric': 'auc',
          'seed': 42}
params.update(study.best_params)
model_xgb = xgb.train(
    params,
    dtrain=dtrain,
    evals=[(dtrain,'train'),(dtest,'test')],
    num_boost_round=3000,
    early_stopping_rounds=100,
    verbose_eval=False
)
y_prob = model_xgb.predict(dtest)
threshold = 0.5
y_pred = (
    y_prob > threshold)
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, label=f'XGBoost (AUC = {roc_auc:.3f})')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
plt.legend()
plt.savefig('ROC_curve_1day.png', dpi=300)
plt.show()

# %% [markdown]
# # Prediction for 2 day

# %%
file_path = '/Users/vladislav/Desktop/Данные/predictions_for_2_days.xlsx'
data = pd.read_excel(file_path,index_col='TRADEDATE')
sifts = range(1,30)

for j in (data.drop('crisis',axis=1)).columns:
    data[j] = data[j].pct_change(fill_method=None)
data_copy = data.copy()
for sh in sifts:
    for j in (data_copy.drop('crisis',axis=1)).columns:
        data[f'{j}_lag_{sh}'] = data[j].shift(sh)
imputer = SimpleImputer(strategy='median')
train = data.iloc[:int(len(data)*0.6),:]
test = data.iloc[int(len(data)*0.6):,:]
x_train = train.drop('crisis',axis=1)
y_train = train['crisis']
x_test = test.drop('crisis',axis=1)
y_test = test['crisis']
x_train = imputer.fit_transform(x_train)
x_test = imputer.transform(x_test)

# %% [markdown]
# # SVM

# %%
def objective(trial):
    params = {'kernel':trial.suggest_categorical('kernel', ['poly','rbf'])}
    if params['kernel'] == 'poly':
        params['degree'] = trial.suggest_int('degree', 2, 5)
    elif params['kernel'] == 'rbf':
        params['gamma'] = trial.suggest_float('gamma', 1e-3, 4,)
    class_weight = {0:(y_train == 0).sum(),
                1:(y_train == 1).sum()}
    svc_model = SVC(kernel='rbf',gamma=3,probability=True,class_weight=class_weight)
    svc_model.fit(x_train,y_train)
    y_pred = svc_model.predict_proba(x_test)[:, 1]
    auc = roc_auc_score(y_test, y_pred)
    return auc

study = optuna.create_study(
    direction='maximize',storage='sqlite:///svc_for_2day_study.db',
    load_if_exists=True,
    study_name='svc_for_2day_study'
)           

study.optimize(
    objective,
    n_trials=ntrials,
    show_progress_bar=True
)
study = optuna.load_study(storage='sqlite:///svc_for_2day_study.db',study_name='svc_for_2day_study')
class_weight = {0:(y_train == 0).sum(),
                1:(y_train == 1).sum()}
best_params = study.best_params
svc_model = SVC(kernel='rbf',probability=True,class_weight=class_weight)
svc_model.set_params(**best_params)
svc_model.fit(x_train,y_train)
y_prob = svc_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test,
        (y_prob > 0.5).astype(int),
        zero_division=0))
print(    "Recall",
    recall_score(
        y_test,
        (y_prob > 0.5).astype(int),
        zero_division=0))
print("F1",
    f1_score(
        y_test,
        (y_prob > 0.5).astype(int),
        zero_division=0))
Accuracy = []
Recall = []
Per = []
Tr = []
F1 = []
for t in np.arange(0,1,0.05):
    y_prob = svc_model.predict_proba(x_test)[:, 1]
    y_pred = (
    y_prob > t
).astype(int)
    Accuracy.append(accuracy_score(y_test, y_pred))
    Recall.append(recall_score(y_test, y_pred, zero_division=0))
    Per.append(precision_score(y_test, y_pred, zero_division=0))
    F1.append(f1_score(y_test, y_pred, zero_division=0))
    Tr.append(t)
plt.figure()
sns.lineplot(x = Tr,y = Accuracy,label = 'Accuracy')
sns.lineplot(x = Tr,y = Recall,label = 'Recall')
sns.lineplot(x = Tr,y = Per, label = 'Precision')
sns.lineplot(x = Tr,y = F1, label = 'F1')
# Out:
# AUC 0.5492622669564223
# Accuracy 0.7643818849449204
# Precision 0.0
# Recall 0.0
# F1 0.0
# <Axes: >

# %% [markdown]
# # XGBoost

# %%
scale_pos_weight = (
        (y_train == 0).sum() /
        (y_train == 1).sum()
)
dtrain = xgb.DMatrix(x_train, label=y_train)
dtest = xgb.DMatrix(x_test, label=y_test)


def objective(trial):
    params = {
        'objective': 'binary:logistic',
        'eval_metric': 'auc',
        'max_depth': trial.suggest_int(
            'max_depth',
            2,
            8
        ),
        'learning_rate': trial.suggest_float(
            'learning_rate',
            0.005,
            0.1,
            log=True
        ),
        'subsample': trial.suggest_float(
            'subsample',
            0.5,
            1.0
        ),

        'colsample_bytree': trial.suggest_float(
            'colsample_bytree',
            0.5,
            1.0
        ),
        'lambda': trial.suggest_float(
            'lambda',
            1e-3,
            10,
            log=True
        ),

        'alpha': trial.suggest_float(
            'alpha',
            1e-3,
            10,
            log=True
        ),
        'gamma': trial.suggest_float(
            'gamma',
            0,
            5
        ),
        'scale_pos_weight': scale_pos_weight,
        'seed': 42
    }
    xgb_model = xgb.train(params, dtrain=dtrain, evals=[(dtrain, 'train'), (dtest, 'test')],
                          num_boost_round=3000, early_stopping_rounds=50, verbose_eval=False)
    y_prob = xgb_model.predict(dtest)
    auc = roc_auc_score(
        y_test,
        y_prob
    )
    return auc


study = optuna.create_study(
    direction='maximize', storage='sqlite:///xgboost_for_2day_study.db',
    load_if_exists=True,
    study_name='xgboost_for_2day_study'
)

study.optimize(
    objective,
    n_trials=ntrials,
    show_progress_bar=True
)
study = optuna.load_study(storage='sqlite:///xgboost_for_2day_study.db',study_name='xgboost_for_2day_study')
params = {'objective': 'binary:logistic',
        'eval_metric': 'auc',
          'seed': 42}
params.update(study.best_params)
model_xgb = xgb.train(
    params,
    dtrain=dtrain,
    evals=[(dtrain,'train'),(dtest,'test')],
    num_boost_round=3000,
    early_stopping_rounds=100,verbose_eval=False
)
y_prob = model_xgb.predict(dtest)
threshold = 0.5
y_pred = (
    y_prob > threshold
).astype(int)
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, y_pred))
print("Precision",precision_score(
        y_test,
        y_pred,
        zero_division=0))
print(
    "Recall",
    recall_score(
        y_test,
        y_pred,
        zero_division=0))
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
Accuracy = []
Recall = []
Per = []
Tr = []
F1 = []
for t in np.arange(0,1,0.05):
    y_prob = model_xgb.predict(dtest)
    y_pred = (
    y_prob > t
).astype(int)
    Accuracy.append(accuracy_score(y_test, y_pred))
    Recall.append(recall_score(y_test, y_pred, zero_division=0))
    Per.append(precision_score(y_test, y_pred, zero_division=0))
    F1.append(f1_score(y_test, y_pred, zero_division=0))
    Tr.append(t)
plt.figure()
sns.lineplot(x = Tr,y = Accuracy,label = 'Accuracy')
sns.lineplot(x = Tr,y = Recall,label = 'Recall')
sns.lineplot(x = Tr,y = Per, label = 'Precision')
sns.lineplot(x = Tr,y = F1, label = 'F1')
# Out:
# AUC 0.8392480217940586
# Accuracy 0.8053855569155447
# Precision 0.7055214723926381
# Recall 0.2987012987012987
# F1 0.4197080291970803
# <Axes: >

# %% [markdown]
# # AdaBoost

# %%
adaboost_model = AdaBoostClassifier(
    estimator=DecisionTreeClassifier(max_depth=10,class_weight={0: np.sum(y_train == 0), 1: np.sum(y_train == 1)}),
    n_estimators=100,
    learning_rate=0.1,
    random_state=42
)
adaboost_model.fit(x_train, y_train)
y_prob = adaboost_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),
        zero_division=0))
print( "Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.7920299876264648
# Accuracy 0.7943696450428397
# Precision 0.6666666666666666
# Recall 0.2545454545454545
# F1 0.0

# %% [markdown]
# # RF

# %%
rf_model = RandomForestClassifier(
    n_estimators=300,
    max_depth=10,
    random_state=42,
    class_weight={0: np.sum(y_train == 0), 1: np.sum(y_train == 1)}
)
rf_model.fit(x_train, y_train)
y_prob = rf_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),     
    zero_division=0))
print( "Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))  
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.752797562725505
# Accuracy 0.7980416156670747
# Precision 0.7570093457943925
# Recall 0.21038961038961038
# F1 0.0

# %% [markdown]
# # EM

# %%
em_model = GaussianMixture(n_components=2, random_state=42)
em_model.fit(x_train,y_train)
y_prob = em_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),
        zero_division=0))
print( "Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.4953905981928399
# Accuracy 0.5960832313341493
# Precision 0.24394785847299813
# Recall 0.34025974025974026
# F1 0.0

# %% [markdown]
# # Logit

# %%
logit_model = LogisticRegression(class_weight={0: np.sum(y_train == 0), 1: np.sum(y_train == 1)}, max_iter=1000)
logit_model.fit(x_train, y_train)
y_prob = logit_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),
        zero_division=0))
print("Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))   
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.7605024279163591
# Accuracy 0.7827417380660955
# Precision 0.5646551724137931
# Recall 0.34025974025974026
# F1 0.0

# %% [markdown]
# # Roc-Auc

# %%
study = optuna.load_study(storage='sqlite:///xgboost_for_2day_study.db',study_name='xgboost_for_2day_study')
params = {'objective': 'binary:logistic',
        'eval_metric': 'auc',
          'seed': 42}
params.update(study.best_params)
model_xgb = xgb.train(
    params,
    dtrain=dtrain,
    evals=[(dtrain,'train'),(dtest,'test')],
    num_boost_round=3000,
    early_stopping_rounds=100,
    verbose_eval=False
)
y_prob = model_xgb.predict(dtest)
threshold = 0.5
y_pred = (
    y_prob > threshold)
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, label=f'XGBoost (AUC = {roc_auc:.3f})')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
plt.legend()
plt.savefig('ROC_curve_2day.png', dpi=300)
plt.show()

# %% [markdown]
# # Prediction for 3 day

# %%
file_path = '/Users/vladislav/Desktop/Данные/predictions_for_3_days.xlsx'
data = pd.read_excel(file_path,index_col='TRADEDATE')
sifts = range(1,30)

for j in (data.drop('crisis',axis=1)).columns:
    data[j] = data[j].pct_change(fill_method=None)
data_copy = data.copy()
for sh in sifts:
    for j in (data_copy.drop('crisis',axis=1)).columns:
        data[f'{j}_lag_{sh}'] = data[j].shift(sh)
imputer = SimpleImputer(strategy='median')
train = data.iloc[:int(len(data)*0.6),:]
test = data.iloc[int(len(data)*0.6):,:]
x_train = train.drop('crisis',axis=1)
y_train = train['crisis']
x_test = test.drop('crisis',axis=1)
y_test = test['crisis']
x_train = imputer.fit_transform(x_train)
x_test = imputer.transform(x_test)

# %% [markdown]
# # SVM

# %%
def objective(trial):
    params = {'kernel':trial.suggest_categorical('kernel', ['poly','rbf'])}
    if params['kernel'] == 'poly':
        params['degree'] = trial.suggest_int('degree', 2, 5)
    elif params['kernel'] == 'rbf':
        params['gamma'] = trial.suggest_float('gamma', 1e-3, 4,)
    class_weight = {0:(y_train == 0).sum(),
                1:(y_train == 1).sum()}
    svc_model = SVC(kernel='rbf',gamma=3,probability=True,class_weight=class_weight)
    svc_model.fit(x_train,y_train)
    y_pred = svc_model.predict_proba(x_test)[:, 1]
    auc = roc_auc_score(y_test, y_pred)
    return auc

study = optuna.create_study(
    direction='maximize',storage='sqlite:///svc_for_3day_study.db',
    load_if_exists=True,
    study_name='svc_for_3day_study'
)           

study.optimize(
    objective,
    n_trials=ntrials,
    show_progress_bar=True
)
class_weight = {0:(y_train == 0).sum(),
                1:(y_train == 1).sum()}
study = optuna.load_study(storage='sqlite:///svc_for_3day_study.db',study_name='svc_for_3day_study')
best_params = study.best_params
svc_model = SVC(kernel='rbf',probability=True,class_weight=class_weight)
svc_model.set_params(**best_params)
svc_model.fit(x_train,y_train)
y_prob = svc_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test,
        (y_prob > 0.5).astype(int),
        zero_division=0))
print(    "Recall",
    recall_score(
        y_test,
        (y_prob > 0.5).astype(int),
        zero_division=0))
print("F1",
    f1_score(
        y_test,
        (y_prob > 0.5).astype(int),
        zero_division=0))
Accuracy = []
Recall = []
Per = []
Tr = []
F1 = []
for t in np.arange(0,1,0.05):
    y_prob = svc_model.predict_proba(x_test)[:, 1]
    y_pred = (
    y_prob > t
).astype(int)
    Accuracy.append(accuracy_score(y_test, y_pred))
    Recall.append(recall_score(y_test, y_pred, zero_division=0))
    Per.append(precision_score(y_test, y_pred, zero_division=0))
    F1.append(f1_score(y_test, y_pred, zero_division=0))
    Tr.append(t)
plt.figure()
sns.lineplot(x = Tr,y = Accuracy,label = 'Accuracy')
sns.lineplot(x = Tr,y = Recall,label = 'Recall')
sns.lineplot(x = Tr,y = Per, label = 'Precision')
sns.lineplot(x = Tr,y = F1, label = 'F1')
# Out:
# AUC 0.5369838494838495
# Accuracy 0.7642375995101041
# Precision 0.0
# Recall 0.0
# F1 0.0
# <Axes: >

# %% [markdown]
# # XGBoost

# %%
scale_pos_weight = (
        (y_train == 0).sum() /
        (y_train == 1).sum()
)
dtrain = xgb.DMatrix(x_train, label=y_train)
dtest = xgb.DMatrix(x_test, label=y_test)


def objective(trial):
    params = {
        'objective': 'binary:logistic',
        'eval_metric': 'auc',
        'max_depth': trial.suggest_int(
            'max_depth',
            2,
            8
        ),
        'learning_rate': trial.suggest_float(
            'learning_rate',
            0.005,
            0.1,
            log=True
        ),
        'subsample': trial.suggest_float(
            'subsample',
            0.5,
            1.0
        ),

        'colsample_bytree': trial.suggest_float(
            'colsample_bytree',
            0.5,
            1.0
        ),
        'lambda': trial.suggest_float(
            'lambda',
            1e-3,
            10,
            log=True
        ),

        'alpha': trial.suggest_float(
            'alpha',
            1e-3,
            10,
            log=True
        ),
        'gamma': trial.suggest_float(
            'gamma',
            0,
            5
        ),
        'scale_pos_weight': scale_pos_weight,
        'seed': 42
    }
    xgb_model = xgb.train(params, dtrain=dtrain, evals=[(dtrain, 'train'), (dtest, 'test')],
                          num_boost_round=3000, early_stopping_rounds=50, verbose_eval=False)
    y_prob = xgb_model.predict(dtest)
    auc = roc_auc_score(
        y_test,
        y_prob
    )
    return auc


study = optuna.create_study(
    direction='maximize', storage='sqlite:///xgboost_for_3day_study.db',
    load_if_exists=True,
    study_name='xgboost_for_3day_study'
)

study.optimize(
    objective,
    n_trials=ntrials,
    show_progress_bar=True
)
study = optuna.load_study(storage='sqlite:///xgboost_for_3day_study.db',study_name='xgboost_for_3day_study')
params = {'objective': 'binary:logistic',
        'eval_metric': 'auc',
          'seed': 42}
params.update(study.best_params)
model_xgb = xgb.train(
    params,
    dtrain=dtrain,
    evals=[(dtrain,'train'),(dtest,'test')],
    num_boost_round=3000,
    early_stopping_rounds=100,
    verbose_eval=False
)
y_prob = model_xgb.predict(dtest)
threshold = 0.5
y_pred = (
    y_prob > threshold
).astype(int)
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, y_pred))
print("Precision",precision_score(
        y_test,
        y_pred,
        zero_division=0))
print(
    "Recall",
    recall_score(
        y_test,
        y_pred,
        zero_division=0))
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
Accuracy = []
Recall = []
Per = []
Tr = []
F1 = []
for t in np.arange(0,1,0.05):
    y_prob = model_xgb.predict(dtest)
    y_pred = (
    y_prob > t
).astype(int)
    Accuracy.append(accuracy_score(y_test, y_pred))
    Recall.append(recall_score(y_test, y_pred, zero_division=0))
    Per.append(precision_score(y_test, y_pred, zero_division=0))
    F1.append(f1_score(y_test, y_pred, zero_division=0))
    Tr.append(t)
plt.figure()
sns.lineplot(x = Tr,y = Accuracy,label = 'Accuracy')
sns.lineplot(x = Tr,y = Recall,label = 'Recall')
sns.lineplot(x = Tr,y = Per, label = 'Precision')
sns.lineplot(x = Tr,y = F1, label = 'F1')
# Out:
# AUC 0.850214368964369
# Accuracy 0.8120024494794856
# Precision 0.7267441860465116
# Recall 0.3246753246753247
# F1 0.4488330341113106
# <Axes: >

# %% [markdown]
# # AdaBoost

# %%
adaboost_model = AdaBoostClassifier(
    estimator=DecisionTreeClassifier(max_depth=10,class_weight={0: np.sum(y_train == 0), 1: np.sum(y_train == 1)}),
    n_estimators=100,
    learning_rate=0.1,
    random_state=42
)
adaboost_model.fit(x_train, y_train)
y_prob = adaboost_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),
        zero_division=0))
print( "Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.7975285131535133
# Accuracy 0.7973055725658298
# Precision 0.6928571428571428
# Recall 0.2519480519480519
# F1 0.0

# %% [markdown]
# # RF

# %%
rf_model = RandomForestClassifier(
    n_estimators=300,
    max_depth=10,
    random_state=42,
    class_weight={0: np.sum(y_train == 0), 1: np.sum(y_train == 1)}
)
rf_model.fit(x_train, y_train)
y_prob = rf_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),     
    zero_division=0))
print( "Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))   
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.7625645188145189
# Accuracy 0.8015921616656461
# Precision 0.7652173913043478
# Recall 0.22857142857142856
# F1 0.0

# %% [markdown]
# # EM

# %%
em_model = GaussianMixture(n_components=2, random_state=42)
em_model.fit(x_train,y_train)
y_prob = em_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),
        zero_division=0))
print( "Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.4926729520479521
# Accuracy 0.5358236374770361
# Precision 0.23842917251051893
# Recall 0.44155844155844154
# F1 0.0

# %% [markdown]
# # Logit

# %%
logit_model = LogisticRegression(class_weight={0: np.sum(y_train == 0), 1: np.sum(y_train == 1)}, max_iter=1000)
logit_model.fit(x_train, y_train)
y_prob = logit_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),
        zero_division=0))
print("Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))   
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.7773434898434898
# Accuracy 0.799755052051439
# Precision 0.625
# Recall 0.37662337662337664
# F1 0.0

# %% [markdown]
# # Roc-Auc

# %%
study = optuna.load_study(storage='sqlite:///xgboost_for_3day_study.db',study_name='xgboost_for_3day_study')
params = {'objective': 'binary:logistic',
        'eval_metric': 'auc',
          'seed': 42}
params.update(study.best_params)
model_xgb = xgb.train(
    params,
    dtrain=dtrain,
    evals=[(dtrain,'train'),(dtest,'test')],
    num_boost_round=3000,
    early_stopping_rounds=100,
    verbose_eval=False
)
y_prob = model_xgb.predict(dtest)
threshold = 0.5
y_pred = (
    y_prob > threshold)
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, label=f'XGBoost (AUC = {roc_auc:.3f})')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
plt.legend()
plt.savefig('ROC_curve_3day.png', dpi=300)
plt.show()

# %% [markdown]
# # Prediction for 4 day

# %%
file_path = '/Users/vladislav/Desktop/Данные/predictions_for_4_days.xlsx'
data = pd.read_excel(file_path,index_col='TRADEDATE')
sifts = range(1,30)
for j in (data.drop('crisis',axis=1)).columns:
    data[j] = data[j].pct_change(fill_method=None)
data_copy = data.copy()
for sh in sifts:
    for j in (data_copy.drop('crisis',axis=1)).columns:
        data[f'{j}_lag_{sh}'] = data[j].shift(sh)
imputer = SimpleImputer(strategy='median')
train = data.iloc[:int(len(data)*0.6),:]
test = data.iloc[int(len(data)*0.6):,:]
x_train = train.drop('crisis',axis=1)
y_train = train['crisis']
x_test = test.drop('crisis',axis=1)
y_test = test['crisis']
x_train = imputer.fit_transform(x_train)
x_test = imputer.transform(x_test)

# %% [markdown]
# # SVM

# %%
def objective(trial):
    params = {'kernel':trial.suggest_categorical('kernel', ['poly','rbf'])}
    if params['kernel'] == 'poly':
        params['degree'] = trial.suggest_int('degree', 2, 5)
    elif params['kernel'] == 'rbf':
        params['gamma'] = trial.suggest_float('gamma', 1e-3, 4,)
    class_weight = {0:(y_train == 0).sum(),
                1:(y_train == 1).sum()}
    svc_model = SVC(kernel='rbf',gamma=3,probability=True,class_weight=class_weight)
    svc_model.fit(x_train,y_train)
    y_pred = svc_model.predict_proba(x_test)[:, 1]
    auc = roc_auc_score(y_test, y_pred)
    return auc

study = optuna.create_study(
    direction='maximize',storage='sqlite:///svc_for_4day_study.db',
    load_if_exists=True,
    study_name='svc_for_4day_study'
)           

study.optimize(
    objective,
    n_trials=ntrials,
    show_progress_bar=True
)
class_weight = {0:(y_train == 0).sum(),
                1:(y_train == 1).sum()}
study = optuna.load_study(storage='sqlite:///svc_for_4day_study.db',study_name='svc_for_4day_study')
best_params = study.best_params
svc_model = SVC(kernel='rbf',probability=True,class_weight=class_weight)
svc_model.set_params(**best_params)
svc_model.fit(x_train,y_train)
y_prob = svc_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test,
        (y_prob > 0.5).astype(int),
        zero_division=0))
print(    "Recall",
    recall_score(
        y_test,
        (y_prob > 0.5).astype(int),
        zero_division=0))
print("F1",
    f1_score(
        y_test,
        (y_prob > 0.5).astype(int),
        zero_division=0))
Accuracy = []
Recall = []
Per = []
Tr = []
F1 = []
for t in np.arange(0,1,0.05):
    y_prob = svc_model.predict_proba(x_test)[:, 1]
    y_pred = (
    y_prob > t
).astype(int)
    Accuracy.append(accuracy_score(y_test, y_pred))
    Recall.append(recall_score(y_test, y_pred, zero_division=0))
    Per.append(precision_score(y_test, y_pred, zero_division=0))
    F1.append(f1_score(y_test, y_pred, zero_division=0))
    Tr.append(t)
plt.figure()
sns.lineplot(x = Tr,y = Accuracy,label = 'Accuracy')
sns.lineplot(x = Tr,y = Recall,label = 'Recall')
sns.lineplot(x = Tr,y = Per, label = 'Precision')
sns.lineplot(x = Tr,y = F1, label = 'F1')
# Out:
# AUC 0.765802947052947
# Accuracy 0.7868952847519902
# Precision 0.5742971887550201
# Recall 0.37142857142857144
# F1 0.45110410094637227
# <Axes: >

# %% [markdown]
# # XGBoost

# %%
scale_pos_weight = (
        (y_train == 0).sum() /
        (y_train == 1).sum()
)
dtrain = xgb.DMatrix(x_train, label=y_train)
dtest = xgb.DMatrix(x_test, label=y_test)


def objective(trial):
    params = {
        'objective': 'binary:logistic',
        'eval_metric': 'auc',
        'max_depth': trial.suggest_int(
            'max_depth',
            2,
            8
        ),
        'learning_rate': trial.suggest_float(
            'learning_rate',
            0.005,
            0.1,
            log=True
        ),
        'subsample': trial.suggest_float(
            'subsample',
            0.5,
            1.0
        ),

        'colsample_bytree': trial.suggest_float(
            'colsample_bytree',
            0.5,
            1.0
        ),
        'lambda': trial.suggest_float(
            'lambda',
            1e-3,
            10,
            log=True
        ),

        'alpha': trial.suggest_float(
            'alpha',
            1e-3,
            10,
            log=True
        ),
        'gamma': trial.suggest_float(
            'gamma',
            0,
            5
        ),
        'scale_pos_weight': scale_pos_weight,
        'seed': 42
    }
    xgb_model = xgb.train(params, dtrain=dtrain, evals=[(dtrain, 'train'), (dtest, 'test')],
                          num_boost_round=3000, early_stopping_rounds=50, verbose_eval=False)
    y_prob = xgb_model.predict(dtest)
    auc = roc_auc_score(
        y_test,
        y_prob
    )
    return auc


study = optuna.create_study(
    direction='maximize', storage='sqlite:///xgboost_for_4day_study.db',
    load_if_exists=True,
    study_name='xgboost_for_4day_study'
)

study.optimize(
    objective,
    n_trials=ntrials,
    show_progress_bar=True
)
study = optuna.load_study(storage='sqlite:///xgboost_for_4day_study.db',study_name='xgboost_for_4day_study')
params = {'objective': 'binary:logistic',
        'eval_metric': 'auc',
          'seed': 42}
params.update(study.best_params)
model_xgb = xgb.train(
    params,
    dtrain=dtrain,
    evals=[(dtrain,'train'),(dtest,'test')],
    num_boost_round=3000,
    early_stopping_rounds=100,
    verbose_eval=False
)
y_prob = model_xgb.predict(dtest)
threshold = 0.5
y_pred = (
    y_prob > threshold
).astype(int)
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, y_pred))
print("Precision",precision_score(
        y_test,
        y_pred,
        zero_division=0))
print(
    "Recall",
    recall_score(
        y_test,
        y_pred,
        zero_division=0))
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
Accuracy = []
Recall = []
Per = []
Tr = []
F1 = []
for t in np.arange(0,1,0.05):
    y_prob = model_xgb.predict(dtest)
    y_pred = (
    y_prob > t
).astype(int)
    Accuracy.append(accuracy_score(y_test, y_pred))
    Recall.append(recall_score(y_test, y_pred, zero_division=0))
    Per.append(precision_score(y_test, y_pred, zero_division=0))
    F1.append(f1_score(y_test, y_pred, zero_division=0))
    Tr.append(t)
plt.figure()
sns.lineplot(x = Tr,y = Accuracy,label = 'Accuracy')
sns.lineplot(x = Tr,y = Recall,label = 'Recall')
sns.lineplot(x = Tr,y = Per, label = 'Precision')
sns.lineplot(x = Tr,y = F1, label = 'F1')
# Out:
# AUC 0.8673805361305361
# Accuracy 0.8254745866503368
# Precision 0.7336448598130841
# Recall 0.4077922077922078
# F1 0.5242070116861436
# <Axes: >

# %% [markdown]
# # AdaBoost

# %%
adaboost_model = AdaBoostClassifier(
    estimator=DecisionTreeClassifier(max_depth=10,class_weight={0: np.sum(y_train == 0), 1: np.sum(y_train == 1)}),
    n_estimators=100,
    learning_rate=0.1,
    random_state=42
)
adaboost_model.fit(x_train, y_train)
y_prob = adaboost_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),
        zero_division=0))
print( "Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.7744089244089243
# Accuracy 0.7703612982241274
# Precision 0.5192307692307693
# Recall 0.35064935064935066
# F1 0.015463917525773196

# %% [markdown]
# # RF

# %%
rf_model = RandomForestClassifier(
    n_estimators=300,
    max_depth=10,
    random_state=42,
    class_weight={0: np.sum(y_train == 0), 1: np.sum(y_train == 1)}
)
rf_model.fit(x_train, y_train)
y_prob = rf_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),     
    zero_division=0))
print( "Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))   
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.768691724941725
# Accuracy 0.7960808328230251
# Precision 0.7363636363636363
# Recall 0.21038961038961038
# F1 0.015463917525773196

# %% [markdown]
# # EM

# %%
em_model = GaussianMixture(n_components=2, random_state=42)
em_model.fit(x_train,y_train)
y_prob = em_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),
        zero_division=0))
print( "Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.5066943473193473
# Accuracy 0.5009185548071035
# Precision 0.24343675417661098
# Recall 0.5298701298701298
# F1 0.015463917525773196

# %% [markdown]
# # Logit

# %%
logit_model = LogisticRegression(class_weight={0: np.sum(y_train == 0), 1: np.sum(y_train == 1)}, max_iter=1000)
logit_model.fit(x_train, y_train)
y_prob = logit_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),
        zero_division=0))
print("Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))  
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.7905656843156843
# Accuracy 0.799755052051439
# Precision 0.625
# Recall 0.37662337662337664
# F1 0.015463917525773196

# %% [markdown]
# # Roc-Auc

# %%
study = optuna.load_study(storage='sqlite:///xgboost_for_4day_study.db',study_name='xgboost_for_4day_study')
params = {'objective': 'binary:logistic',
        'eval_metric': 'auc',
          'seed': 42}
params.update(study.best_params)
model_xgb = xgb.train(
    params,
    dtrain=dtrain,
    evals=[(dtrain,'train'),(dtest,'test')],
    num_boost_round=3000,
    early_stopping_rounds=100,
    verbose_eval=False
)
y_prob = model_xgb.predict(dtest)
threshold = 0.5
y_pred = (
    y_prob > threshold)
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, label=f'XGBoost (AUC = {roc_auc:.3f})')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
plt.legend()
plt.savefig('ROC_curve_4day.png', dpi=300)
plt.show()

# %% [markdown]
# # Prediction for 5 day

# %%
file_path = '/Users/vladislav/Desktop/Данные/predictions_for_5_days.xlsx'
data = pd.read_excel(file_path,index_col='TRADEDATE')
sifts = range(1,30)
for j in (data.drop('crisis',axis=1)).columns:
    data[j] = data[j].pct_change(fill_method=None)
data_copy = data.copy()
for sh in sifts:
    for j in (data_copy.drop('crisis',axis=1)).columns:
        data[f'{j}_lag_{sh}'] = data[j].shift(sh)
imputer = SimpleImputer(strategy='median')
train = data.iloc[:int(len(data)*0.6),:]
test = data.iloc[int(len(data)*0.6):,:]
x_train = train.drop('crisis',axis=1)
y_train = train['crisis']
x_test = test.drop('crisis',axis=1)
y_test = test['crisis']
x_train = imputer.fit_transform(x_train)
x_test = imputer.transform(x_test)

# %% [markdown]
# # SVM

# %%
def objective(trial):
    params = {'kernel':trial.suggest_categorical('kernel', ['poly','rbf'])}
    if params['kernel'] == 'poly':
        params['degree'] = trial.suggest_int('degree', 2, 5)
    elif params['kernel'] == 'rbf':
        params['gamma'] = trial.suggest_float('gamma', 1e-3, 4,)
    class_weight = {0:(y_train == 0).sum(),
                1:(y_train == 1).sum()}
    svc_model = SVC(kernel='rbf',gamma=3,probability=True,class_weight=class_weight)
    svc_model.fit(x_train,y_train)
    y_pred = svc_model.predict_proba(x_test)[:, 1]
    auc = roc_auc_score(y_test, y_pred)
    return auc
study = optuna.create_study(
    direction='maximize',storage='sqlite:///svc_for_5day_study.db',
    load_if_exists=True,
    study_name='svc_for_5day_study'
)           

study.optimize(
    objective,
    n_trials=ntrials,
    show_progress_bar=True
)
class_weight = {0:(y_train == 0).sum(),
                1:(y_train == 1).sum()}
study = optuna.load_study(storage='sqlite:///svc_for_5day_study.db',study_name='svc_for_5day_study')
best_params = study.best_params
svc_model = SVC(kernel='rbf',probability=True,class_weight=class_weight)
svc_model.set_params(**best_params)
svc_model.fit(x_train,y_train)
y_prob = svc_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test,
        (y_prob > 0.5).astype(int),
        zero_division=0))
print(    "Recall",
    recall_score(
        y_test,
        (y_prob > 0.5).astype(int),
        zero_division=0))
print("F1",
    f1_score(
        y_test,
        (y_prob > 0.5).astype(int),
        zero_division=0))
Accuracy = []
Recall = []
Per = []
Tr = []
F1 = []
for t in np.arange(0,1,0.05):
    y_prob = svc_model.predict_proba(x_test)[:, 1]
    y_pred = (
    y_prob > t
).astype(int)
    Accuracy.append(accuracy_score(y_test, y_pred))
    Recall.append(recall_score(y_test, y_pred, zero_division=0))
    Per.append(precision_score(y_test, y_pred, zero_division=0))
    F1.append(f1_score(y_test, y_pred, zero_division=0))
    Tr.append(t)
plt.figure()
sns.lineplot(x = Tr,y = Accuracy,label = 'Accuracy')
sns.lineplot(x = Tr,y = Recall,label = 'Recall')
sns.lineplot(x = Tr,y = Per, label = 'Precision')
sns.lineplot(x = Tr,y = F1, label = 'F1')
# Out:
# AUC 0.5439069350857643
# Accuracy 0.7640931372549019
# Precision 0.0
# Recall 0.0
# F1 0.0
# <Axes: >

# %% [markdown]
# # XGBoost

# %%
scale_pos_weight = (
        (y_train == 0).sum() /
        (y_train == 1).sum()
)
dtrain = xgb.DMatrix(x_train, label=y_train)
dtest = xgb.DMatrix(x_test, label=y_test)


def objective(trial):
    params = {
        'objective': 'binary:logistic',
        'eval_metric': 'auc',
        'max_depth': trial.suggest_int(
            'max_depth',
            2,
            8
        ),
        'learning_rate': trial.suggest_float(
            'learning_rate',
            0.005,
            0.1,
            log=True
        ),
        'subsample': trial.suggest_float(
            'subsample',
            0.5,
            1.0
        ),

        'colsample_bytree': trial.suggest_float(
            'colsample_bytree',
            0.5,
            1.0
        ),
        'lambda': trial.suggest_float(
            'lambda',
            1e-3,
            10,
            log=True
        ),

        'alpha': trial.suggest_float(
            'alpha',
            1e-3,
            10,
            log=True
        ),
        'gamma': trial.suggest_float(
            'gamma',
            0,
            5
        ),
        'scale_pos_weight': scale_pos_weight,
        'seed': 42
    }
    xgb_model = xgb.train(params, dtrain=dtrain, evals=[(dtrain, 'train'), (dtest, 'test')],
                          num_boost_round=3000, early_stopping_rounds=50, verbose_eval=False)
    y_prob = xgb_model.predict(dtest)
    auc = roc_auc_score(
        y_test,
        y_prob
    )
    return auc


study = optuna.create_study(
    direction='maximize', storage='sqlite:///xgboost_for_5day_study.db',
    load_if_exists=True,
    study_name='xgboost_for_5day_study'
)

study.optimize(
    objective,
    n_trials=ntrials,
    show_progress_bar=True
)
study = optuna.load_study(storage='sqlite:///xgboost_for_5day_study.db',study_name='xgboost_for_5day_study')
params = {'objective': 'binary:logistic',
        'eval_metric': 'auc',
          'seed': 42}
params.update(study.best_params)
model_xgb = xgb.train(
    params,
    dtrain=dtrain,
    evals=[(dtrain,'train'),(dtest,'test')],
    num_boost_round=3000,
    early_stopping_rounds=100,
    verbose_eval=False
)
y_prob = model_xgb.predict(dtest)
threshold = 0.5
y_pred = (
    y_prob > threshold
).astype(int)
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, y_pred))
print("Precision",precision_score(
        y_test,
        y_pred,
        zero_division=0))
print(
    "Recall",
    recall_score(
        y_test,
        y_pred,
        zero_division=0))
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
Accuracy = []
Recall = []
Per = []
Tr = []
F1 = []
for t in np.arange(0,1,0.05):
    y_prob = model_xgb.predict(dtest)
    y_pred = (
    y_prob > t
).astype(int)
    Accuracy.append(accuracy_score(y_test, y_pred))
    Recall.append(recall_score(y_test, y_pred, zero_division=0))
    Per.append(precision_score(y_test, y_pred, zero_division=0))
    F1.append(f1_score(y_test, y_pred, zero_division=0))
    Tr.append(t)
plt.figure()
sns.lineplot(x = Tr,y = Accuracy,label = 'Accuracy')
sns.lineplot(x = Tr,y = Recall,label = 'Recall')
sns.lineplot(x = Tr,y = Per, label = 'Precision')
sns.lineplot(x = Tr,y = F1, label = 'F1')
# Out:
# AUC 0.8706485174809152
# Accuracy 0.8131127450980392
# Precision 0.7150537634408602
# Recall 0.34545454545454546
# F1 0.4658493870402802
# <Axes: >

# %% [markdown]
# # AdaBoost

# %%
adaboost_model = AdaBoostClassifier(
    estimator=DecisionTreeClassifier(max_depth=10,class_weight={0: np.sum(y_train == 0), 1: np.sum(y_train == 1)}),
    n_estimators=100,
    learning_rate=0.1,
    random_state=42
)
adaboost_model.fit(x_train, y_train)
y_prob = adaboost_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),
        zero_division=0))
print( "Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.7839344296441328
# Accuracy 0.7879901960784313
# Precision 0.6089385474860335
# Recall 0.2831168831168831
# F1 0.0051813471502590676

# %% [markdown]
# # RF

# %%
rf_model = RandomForestClassifier(
    n_estimators=300,
    max_depth=10,
    random_state=42,
    class_weight={0: np.sum(y_train == 0), 1: np.sum(y_train == 1)}
)
rf_model.fit(x_train, y_train)
y_prob = rf_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),     
    zero_division=0))
print( "Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))   
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.7734635853320697
# Accuracy 0.8008578431372549
# Precision 0.7777777777777778
# Recall 0.21818181818181817
# F1 0.0051813471502590676

# %% [markdown]
# # EM

# %%
em_model = GaussianMixture(n_components=2, random_state=42)
em_model.fit(x_train,y_train)
y_prob = em_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),
        zero_division=0))
print( "Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.4988002374530041
# Accuracy 0.5386029411764706
# Precision 0.24794520547945206
# Recall 0.4701298701298701
# F1 0.0051813471502590676

# %% [markdown]
# # Logit

# %%
logit_model = LogisticRegression(class_weight={0: np.sum(y_train == 0), 1: np.sum(y_train == 1)}, max_iter=1000)
logit_model.fit(x_train, y_train)
y_prob = logit_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),
        zero_division=0))
print("Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))   
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.8038284089607265
# Accuracy 0.7990196078431373
# Precision 0.6108949416342413
# Recall 0.4077922077922078
# F1 0.0051813471502590676

# %% [markdown]
# # Roc-Auc

# %%
study = optuna.load_study(storage='sqlite:///xgboost_for_5day_study.db',study_name='xgboost_for_5day_study')
params = {'objective': 'binary:logistic',
        'eval_metric': 'auc',
          'seed': 42}
params.update(study.best_params)
model_xgb = xgb.train(
    params,
    dtrain=dtrain,
    evals=[(dtrain,'train'),(dtest,'test')],
    num_boost_round=3000,
    early_stopping_rounds=100,
    verbose_eval=False
)
y_prob = model_xgb.predict(dtest)
threshold = 0.5
y_pred = (
    y_prob > threshold)
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, label=f'XGBoost (AUC = {roc_auc:.3f})')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
plt.legend()
plt.savefig('ROC_curve_5day.png', dpi=300)
plt.show()

# %% [markdown]
# # Prediction for 6 days

# %%
file_path = '/Users/vladislav/Desktop/Данные/predictions_for_6_days.xlsx'
data = pd.read_excel(file_path,index_col='TRADEDATE')
sifts = range(1,30)
for j in (data.drop('crisis',axis=1)).columns:
    data[j] = data[j].pct_change(fill_method=None)
data_copy = data.copy()
for sh in sifts:
    for j in (data_copy.drop('crisis',axis=1)).columns:
        data[f'{j}_lag_{sh}'] = data[j].shift(sh)
imputer = SimpleImputer(strategy='median')
train = data.iloc[:int(len(data)*0.6),:]
test = data.iloc[int(len(data)*0.6):,:]
x_train = train.drop('crisis',axis=1)
y_train = train['crisis']
x_test = test.drop('crisis',axis=1)
y_test = test['crisis']
x_train = imputer.fit_transform(x_train)
x_test = imputer.transform(x_test)

# %% [markdown]
# # SVM

# %%
def objective(trial):
    params = {'kernel':trial.suggest_categorical('kernel', ['poly','rbf'])}
    if params['kernel'] == 'poly':
        params['degree'] = trial.suggest_int('degree', 2, 5)
    elif params['kernel'] == 'rbf':
        params['gamma'] = trial.suggest_float('gamma', 1e-3, 4,)
    class_weight = {0:(y_train == 0).sum(),
                1:(y_train == 1).sum()}
    svc_model = SVC(kernel='rbf',gamma=3,probability=True,class_weight=class_weight)
    svc_model.fit(x_train,y_train)
    y_pred = svc_model.predict_proba(x_test)[:, 1]
    auc = roc_auc_score(y_test, y_pred)
    return auc
study = optuna.create_study(
    direction='maximize',storage='sqlite:///svc_for_6day_study.db',
    load_if_exists=True,
    study_name='svc_for_6day_study'
)           

study.optimize(
    objective,
    n_trials=ntrials,
    show_progress_bar=True
)
class_weight = {0:(y_train == 0).sum(),
                1:(y_train == 1).sum()}
study = optuna.load_study(storage='sqlite:///svc_for_6day_study.db',study_name='svc_for_6day_study')
best_params = study.best_params
svc_model = SVC(kernel='rbf',probability=True,class_weight=class_weight)
svc_model.set_params(**best_params)
svc_model.fit(x_train,y_train)
y_prob = svc_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test,
        (y_prob > 0.5).astype(int),
        zero_division=0))
print(    "Recall",
    recall_score(
        y_test,
        (y_prob > 0.5).astype(int),
        zero_division=0))
print("F1",
    f1_score(
        y_test,
        (y_prob > 0.5).astype(int),
        zero_division=0))
Accuracy = []
Recall = []
Per = []
Tr = []
F1 = []
for t in np.arange(0,1,0.05):
    y_prob = svc_model.predict_proba(x_test)[:, 1]
    y_pred = (
    y_prob > t
).astype(int)
    Accuracy.append(accuracy_score(y_test, y_pred))
    Recall.append(recall_score(y_test, y_pred, zero_division=0))
    Per.append(precision_score(y_test, y_pred, zero_division=0))
    F1.append(f1_score(y_test, y_pred, zero_division=0))
    Tr.append(t)
plt.figure()
sns.lineplot(x = Tr,y = Accuracy,label = 'Accuracy')
sns.lineplot(x = Tr,y = Recall,label = 'Recall')
sns.lineplot(x = Tr,y = Per, label = 'Precision')
sns.lineplot(x = Tr,y = F1, label = 'F1')
# Out:
# AUC 0.8063299971880565
# Accuracy 0.7886029411764706
# Precision 0.588495575221239
# Recall 0.34545454545454546
# F1 0.4353518821603928
# <Axes: >

# %% [markdown]
# # XGBoost

# %%
scale_pos_weight = (
        (y_train == 0).sum() /
        (y_train == 1).sum()
)
dtrain = xgb.DMatrix(x_train, label=y_train)
dtest = xgb.DMatrix(x_test, label=y_test)


def objective(trial):
    params = {
        'objective': 'binary:logistic',
        'eval_metric': 'auc',
        'max_depth': trial.suggest_int(
            'max_depth',
            2,
            8
        ),
        'learning_rate': trial.suggest_float(
            'learning_rate',
            0.005,
            0.1,
            log=True
        ),
        'subsample': trial.suggest_float(
            'subsample',
            0.5,
            1.0
        ),

        'colsample_bytree': trial.suggest_float(
            'colsample_bytree',
            0.5,
            1.0
        ),
        'lambda': trial.suggest_float(
            'lambda',
            1e-3,
            10,
            log=True
        ),

        'alpha': trial.suggest_float(
            'alpha',
            1e-3,
            10,
            log=True
        ),
        'gamma': trial.suggest_float(
            'gamma',
            0,
            5
        ),
        'scale_pos_weight': scale_pos_weight,
        'seed': 42
    }
    xgb_model = xgb.train(params, dtrain=dtrain, evals=[(dtrain, 'train'), (dtest, 'test')],
                          num_boost_round=3000, early_stopping_rounds=50, verbose_eval=False)
    y_prob = xgb_model.predict(dtest)
    auc = roc_auc_score(
        y_test,
        y_prob
    )
    return auc


study = optuna.create_study(
    direction='maximize', storage='sqlite:///xgboost_for_6day_study.db',
    load_if_exists=True,
    study_name='xgboost_for_6day_study'
)

study.optimize(
    objective,
    n_trials=ntrials,
    show_progress_bar=True
)
study = optuna.load_study(storage='sqlite:///xgboost_for_6day_study.db',study_name='xgboost_for_6day_study')
params = {'objective': 'binary:logistic',
        'eval_metric': 'auc',
          'seed': 42}
params.update(study.best_params)
model_xgb = xgb.train(
    params,
    dtrain=dtrain,
    evals=[(dtrain,'train'),(dtest,'test')],
    num_boost_round=3000,
    early_stopping_rounds=100,
    verbose_eval=False
)
y_prob = model_xgb.predict(dtest)
threshold = 0.5
y_pred = (
    y_prob > threshold
).astype(int)
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, y_pred))
print("Precision",precision_score(
        y_test,
        y_pred,
        zero_division=0))
print(
    "Recall",
    recall_score(
        y_test,
        y_pred,
        zero_division=0))
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
Accuracy = []
Recall = []
Per = []
Tr = []
F1 = []
for t in np.arange(0,1,0.05):
    y_prob = model_xgb.predict(dtest)
    y_pred = (
    y_prob > t
).astype(int)
    Accuracy.append(accuracy_score(y_test, y_pred))
    Recall.append(recall_score(y_test, y_pred, zero_division=0))
    Per.append(precision_score(y_test, y_pred, zero_division=0))
    F1.append(f1_score(y_test, y_pred, zero_division=0))
    Tr.append(t)
plt.figure()
sns.lineplot(x = Tr,y = Accuracy,label = 'Accuracy')
sns.lineplot(x = Tr,y = Recall,label = 'Recall')
sns.lineplot(x = Tr,y = Per, label = 'Precision')
sns.lineplot(x = Tr,y = F1, label = 'F1')
# Out:
# AUC 0.8795384246867807
# Accuracy 0.8192401960784313
# Precision 0.7295918367346939
# Recall 0.37142857142857144
# F1 0.49225473321858865
# <Axes: >

# %% [markdown]
# # AdaBoost

# %%
adaboost_model = AdaBoostClassifier(
    estimator=DecisionTreeClassifier(max_depth=10,class_weight={0: np.sum(y_train == 0), 1: np.sum(y_train == 1)}),
    n_estimators=100,
    learning_rate=0.1,
    random_state=42
)
adaboost_model.fit(x_train, y_train)
y_prob = adaboost_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),
        zero_division=0))
print( "Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.7695966423312053
# Accuracy 0.7640931372549019
# Precision 0.5
# Recall 0.3168831168831169
# F1 0.0103359173126615

# %% [markdown]
# # RF

# %%
rf_model = RandomForestClassifier(
    n_estimators=300,
    max_depth=10,
    random_state=42,
    class_weight={0: np.sum(y_train == 0), 1: np.sum(y_train == 1)}
)
rf_model.fit(x_train, y_train)
y_prob = rf_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),     
    zero_division=0))
print( "Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))   
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.776612962017934
# Accuracy 0.7965686274509803
# Precision 0.7345132743362832
# Recall 0.21558441558441557
# F1 0.0103359173126615

# %% [markdown]
# # EM

# %%
em_model = GaussianMixture(n_components=2, random_state=42)
em_model.fit(x_train,y_train)
y_prob = em_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),
        zero_division=0))
print( "Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.5038200772763723
# Accuracy 0.3946078431372549
# Precision 0.23342175066312998
# Recall 0.6857142857142857
# F1 0.0103359173126615

# %% [markdown]
# # Logit

# %%
logit_model = LogisticRegression(class_weight={0: np.sum(y_train == 0), 1: np.sum(y_train == 1)}, max_iter=1000)
logit_model.fit(x_train, y_train)
y_prob = logit_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),
        zero_division=0))
print("Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))   
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.8188733479832117
# Accuracy 0.8082107843137255
# Precision 0.65
# Recall 0.4051948051948052
# F1 0.0103359173126615

# %% [markdown]
# # Roc-Auc

# %%
study = optuna.load_study(storage='sqlite:///xgboost_for_6day_study.db',study_name='xgboost_for_6day_study')
params = {'objective': 'binary:logistic',
        'eval_metric': 'auc',
          'seed': 42}
params.update(study.best_params)
model_xgb = xgb.train(
    params,
    dtrain=dtrain,
    evals=[(dtrain,'train'),(dtest,'test')],
    num_boost_round=3000,
    early_stopping_rounds=100,
    verbose_eval=False
)
y_prob = model_xgb.predict(dtest)
threshold = 0.5
y_pred = (
    y_prob > threshold)
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, label=f'XGBoost (AUC = {roc_auc:.3f})')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
plt.legend()
plt.savefig('ROC_curve_6day.png', dpi=300)
plt.show()

# %% [markdown]
# # Prediction for 7 days

# %%
file_path = '/Users/vladislav/Desktop/Данные/predictions_for_6_days.xlsx'
data = pd.read_excel(file_path,index_col='TRADEDATE')
sifts = range(1,30)
for j in (data.drop('crisis',axis=1)).columns:
    data[j] = data[j].pct_change(fill_method=None)
data_copy = data.copy()
for sh in sifts:
    for j in (data_copy.drop('crisis',axis=1)).columns:
        data[f'{j}_lag_{sh}'] = data[j].shift(sh)
imputer = SimpleImputer(strategy='median')
train = data.iloc[:int(len(data)*0.6),:]
test = data.iloc[int(len(data)*0.6):,:]
x_train = train.drop('crisis',axis=1)
y_train = train['crisis']
x_test = test.drop('crisis',axis=1)
y_test = test['crisis']
x_train = imputer.fit_transform(x_train)
x_test = imputer.transform(x_test)

# %% [markdown]
# # SVM

# %%
def objective(trial):
    params = {'kernel':trial.suggest_categorical('kernel', ['poly','rbf'])}
    if params['kernel'] == 'poly':
        params['degree'] = trial.suggest_int('degree', 2, 5)
    elif params['kernel'] == 'rbf':
        params['gamma'] = trial.suggest_float('gamma', 1e-3, 4,)
    class_weight = {0:(y_train == 0).sum(),
                1:(y_train == 1).sum()}
    svc_model = SVC(kernel='rbf',gamma=3,probability=True,class_weight=class_weight)
    svc_model.fit(x_train,y_train)
    y_pred = svc_model.predict_proba(x_test)[:, 1]
    auc = roc_auc_score(y_test, y_pred)
    return auc
study = optuna.create_study(
    direction='maximize',storage='sqlite:///svc_for_7day_study.db',
    load_if_exists=True,
    study_name='svc_for_7day_study'
)           

study.optimize(
    objective,
    n_trials=ntrials,
    show_progress_bar=True
)
class_weight = {0:(y_train == 0).sum(),
                1:(y_train == 1).sum()}
study = optuna.load_study(storage='sqlite:///svc_for_7day_study.db',study_name='svc_for_7day_study')
best_params = study.best_params
svc_model = SVC(kernel='rbf',probability=True,class_weight=class_weight)
svc_model.set_params(**best_params)
svc_model.fit(x_train,y_train)
y_prob = svc_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test,
        (y_prob > 0.5).astype(int),
        zero_division=0))
print(    "Recall",
    recall_score(
        y_test,
        (y_prob > 0.5).astype(int),
        zero_division=0))
print("F1",
    f1_score(
        y_test,
        (y_prob > 0.5).astype(int),
        zero_division=0))
Accuracy = []
Recall = []
Per = []
Tr = []
F1 = []
for t in np.arange(0,1,0.05):
    y_prob = svc_model.predict_proba(x_test)[:, 1]
    y_pred = (
    y_prob > t
).astype(int)
    Accuracy.append(accuracy_score(y_test, y_pred))
    Recall.append(recall_score(y_test, y_pred, zero_division=0))
    Per.append(precision_score(y_test, y_pred, zero_division=0))
    F1.append(f1_score(y_test, y_pred, zero_division=0))
    Tr.append(t)
plt.figure()
sns.lineplot(x = Tr,y = Accuracy,label = 'Accuracy')
sns.lineplot(x = Tr,y = Recall,label = 'Recall')
sns.lineplot(x = Tr,y = Per, label = 'Precision')
sns.lineplot(x = Tr,y = F1, label = 'F1')
# Out:
# AUC 0.5504452243826743
# Accuracy 0.7640931372549019
# Precision 0.0
# Recall 0.0
# F1 0.0
# <Axes: >

# %% [markdown]
# # XGBoost

# %%
scale_pos_weight = (
        (y_train == 0).sum() /
        (y_train == 1).sum()
)
dtrain = xgb.DMatrix(x_train, label=y_train)
dtest = xgb.DMatrix(x_test, label=y_test)


def objective(trial):
    params = {
        'objective': 'binary:logistic',
        'eval_metric': 'auc',
        'max_depth': trial.suggest_int(
            'max_depth',
            2,
            8
        ),
        'learning_rate': trial.suggest_float(
            'learning_rate',
            0.005,
            0.1,
            log=True
        ),
        'subsample': trial.suggest_float(
            'subsample',
            0.5,
            1.0
        ),

        'colsample_bytree': trial.suggest_float(
            'colsample_bytree',
            0.5,
            1.0
        ),
        'lambda': trial.suggest_float(
            'lambda',
            1e-3,
            10,
            log=True
        ),

        'alpha': trial.suggest_float(
            'alpha',
            1e-3,
            10,
            log=True
        ),
        'gamma': trial.suggest_float(
            'gamma',
            0,
            5
        ),
        'scale_pos_weight': scale_pos_weight,
        'seed': 42
    }
    xgb_model = xgb.train(params, dtrain=dtrain, evals=[(dtrain, 'train'), (dtest, 'test')],
                          num_boost_round=3000, early_stopping_rounds=50, verbose_eval=False)
    y_prob = xgb_model.predict(dtest)
    auc = roc_auc_score(
        y_test,
        y_prob
    )
    return auc


study = optuna.create_study(
    direction='maximize', storage='sqlite:///xgboost_for_7day_study.db',
    load_if_exists=True,
    study_name='xgboost_for_7day_study'
)

study.optimize(
    objective,
    n_trials=ntrials,
    show_progress_bar=True
)
study = optuna.load_study(storage='sqlite:///xgboost_for_7day_study.db',study_name='xgboost_for_7day_study')
params = {'objective': 'binary:logistic',
        'eval_metric': 'auc',
          'seed': 42}
params.update(study.best_params)
model_xgb = xgb.train(
    params,
    dtrain=dtrain,
    evals=[(dtrain,'train'),(dtest,'test')],
    num_boost_round=3000,
    early_stopping_rounds=100,
    verbose_eval=False
)
y_prob = model_xgb.predict(dtest)
threshold = 0.5
y_pred = (
    y_prob > threshold
).astype(int)
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, y_pred))
print("Precision",precision_score(
        y_test,
        y_pred,
        zero_division=0))
print(
    "Recall",
    recall_score(
        y_test,
        y_pred,
        zero_division=0))
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
Accuracy = []
Recall = []
Per = []
Tr = []
F1 = []
for t in np.arange(0,1,0.05):
    y_prob = model_xgb.predict(dtest)
    y_pred = (y_prob > t
).astype(int)
    Accuracy.append(accuracy_score(y_test, y_pred))
    Recall.append(recall_score(y_test, y_pred, zero_division=0))
    Per.append(precision_score(y_test, y_pred, zero_division=0))
    F1.append(f1_score(y_test, y_pred, zero_division=0))
    Tr.append(t)
plt.figure()
sns.lineplot(x = Tr,y = Accuracy,label = 'Accuracy')
sns.lineplot(x = Tr,y = Recall,label = 'Recall')
sns.lineplot(x = Tr,y = Per, label = 'Precision')
sns.lineplot(x = Tr,y = F1, label = 'F1')
# Out:
# AUC 0.8799716722731958
# Accuracy 0.8235294117647058
# Precision 0.7255813953488373
# Recall 0.4051948051948052
# F1 0.52
# <Axes: >

# %% [markdown]
# # AdaBoost

# %%
adaboost_model = AdaBoostClassifier(
    estimator=DecisionTreeClassifier(max_depth=10, class_weight={0: np.sum(y_train == 0), 1: np.sum(y_train == 1)}),
    n_estimators=100,
    learning_rate=0.1,
    random_state=42
)
adaboost_model.fit(x_train, y_train)
y_prob = adaboost_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),
        zero_division=0))
print( "Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.7695966423312053
# Accuracy 0.7640931372549019
# Precision 0.5
# Recall 0.3168831168831169
# F1 0.015463917525773196

# %% [markdown]
# # RF

# %%
rf_model = RandomForestClassifier(
    n_estimators=300,
    max_depth=10,
    random_state=42,
    class_weight={0: np.sum(y_train == 0), 1: np.sum(y_train == 1)}
)
rf_model.fit(x_train, y_train)
y_prob = rf_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),     
    zero_division=0))
print( "Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))   
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.776612962017934
# Accuracy 0.7965686274509803
# Precision 0.7345132743362832
# Recall 0.21558441558441557
# F1 0.015463917525773196

# %% [markdown]
# # EM

# %%
em_model = GaussianMixture(n_components=2, random_state=42)
em_model.fit(x_train,y_train)
y_prob = em_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),
        zero_division=0))
print( "Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.5038200772763723
# Accuracy 0.3946078431372549
# Precision 0.23342175066312998
# Recall 0.6857142857142857
# F1 0.015463917525773196

# %% [markdown]
# # Logit

# %%
logit_model = LogisticRegression(class_weight={0: np.sum(y_train == 0), 1: np.sum(y_train == 1)}, max_iter=1000)
logit_model.fit(x_train, y_train)
y_prob = logit_model.predict_proba(x_test)[:, 1]
print("AUC",roc_auc_score(y_test, y_prob))
print("Accuracy",accuracy_score(y_test, (y_prob > 0.5).astype(int)))
print("Precision",precision_score(
        y_test, (y_prob > 0.5).astype(int),
        zero_division=0))
print("Recall",
    recall_score(y_test, (y_prob > 0.5).astype(int),zero_division=0))  
print("F1",
    f1_score(
        y_test,
        y_pred,
        zero_division=0))
# Out:
# AUC 0.8188733479832117
# Accuracy 0.8082107843137255
# Precision 0.65
# Recall 0.4051948051948052
# F1 0.015463917525773196

# %% [markdown]
# # Roc-Auc

# %%
study = optuna.load_study(storage='sqlite:///xgboost_for_7day_study.db',study_name='xgboost_for_7day_study')
params = {'objective': 'binary:logistic',
        'eval_metric': 'auc',
          'seed': 42}
params.update(study.best_params)
model_xgb = xgb.train(
    params,
    dtrain=dtrain,
    evals=[(dtrain,'train'),(dtest,'test')],
    num_boost_round=3000,
    early_stopping_rounds=100,
    verbose_eval=False
)
y_prob = model_xgb.predict(dtest)
threshold = 0.5
y_pred = (
    y_prob > threshold)
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, label=f'XGBoost (AUC = {roc_auc:.3f})')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
plt.legend()
plt.savefig('ROC_curve_7day.png', dpi=300)
plt.show()

# %% [markdown]
# # Эконометрический подход

# %%
file_path = '/Users/vladislav/Desktop/Данные/predictions_for_1_days.xlsx'
data = pd.read_excel(file_path,index_col='TRADEDATE')
sifts = range(1,30)

for j in (data.drop('crisis',axis=1)).columns:
    data[j] = data[j].pct_change(fill_method=None)
data_copy = data.copy()
for sh in sifts:
    for j in (data_copy.drop('crisis',axis=1)).columns:
        data[f'{j}_lag_{sh}'] = data[j].shift(sh)
imputer = SimpleImputer(strategy='median')
x_train = train.drop('crisis',axis=1)
y_train = train['crisis']
x_train = imputer.fit_transform(x_train)
x_train = sm.add_constant(x_train)
logit_model = sm.Logit(y_train, x_train)
result = logit_model.fit(cov_type='HC3')
res = result.summary()
latex = res.as_latex()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.180876
#          Iterations 29

# %%
print(res)
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 crisis   No. Observations:                 2447
# Model:                          Logit   Df Residuals:                     2026
# Method:                           MLE   Df Model:                          420
# Date:                Fri, 01 May 2026   Pseudo R-squ.:                  0.6662
# Time:                        17:38:59   Log-Likelihood:                -442.60
# converged:                       True   LL-Null:                       -1325.8
# Covariance Type:                  HC3   LLR p-value:                3.604e-164
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.6877      0.286    -12.895      0.000      -4.248      -3.127
# x1           -23.5639     24.584     -0.959      0.338     -71.747      24.619
# x2            22.4844     24.329      0.924      0.355     -25.199      70.168
# x3             3.4007      2.510      1.355      0.175      -1.519       8.320
# x4           -37.1556     34.804     -1.068      0.286    -105.370      31.059
# x5            21.4486     38.310      0.560      0.576     -53.637      96.534
# x6            29.6769     38.148      0.778      0.437     -45.093     104.446
# x7           -26.4833     17.087     -1.550      0.121     -59.974       7.008
# x8            -0.5481      1.999     -0.274      0.784      -4.466       3.369
# x399          35.9589     24.503      1.468      0.142     -12.067      83.985
# x400          -0.2258      1.949     -0.116      0.908      -4.046       3.594
# x401         -14.2163     49.814     -0.285      0.775    -111.850      83.418
# x402         -17.6972     93.082     -0.190      0.849    -200.134     164.740
# x403           5.0867     41.463      0.123      0.902     -76.178      86.352
# x404         -27.3610     38.830     -0.705      0.481    -103.467      48.745
# x405          -9.6324    112.354     -0.086      0.932    -229.841     210.577
# x406         -39.0448     47.832     -0.816      0.414    -132.794      54.704
# x407         -40.9120     33.098     -1.236      0.216    -105.783      23.959
# x408          55.8901     32.898      1.699      0.089      -8.590     120.370
# x409           1.6152      2.578      0.626      0.531      -3.438       6.668
# x410          23.4432     26.944      0.870      0.384     -29.365      76.252
# x411         -22.7227     24.662     -0.921      0.357     -71.059      25.614
# x412          13.2323     37.149      0.356      0.722     -59.577      86.042
# x413          -4.8890     22.388     -0.218      0.827     -48.768      38.990
# x414          -4.5860      1.875     -2.446      0.014      -8.261      -0.911
# x415          62.8850     42.280      1.487      0.137     -19.983     145.753
# x416          10.1054     22.224      0.455      0.649     -33.454      53.664
# x417         -26.4427     33.644     -0.786      0.432     -92.384      39.498
# x418          11.3386     27.763      0.408      0.683     -43.075      65.753
# x419          34.8512     95.528      0.365      0.715    -152.381     222.083
# x420           5.3784     49.321      0.109      0.913     -91.288     102.045
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.22 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.

# %%
print(latex)
# Out:
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}   &      crisis      & \textbf{  No. Observations:  } &     2447    \\
# \textbf{Model:}           &      Logit       & \textbf{  Df Residuals:      } &     2026    \\
# \textbf{Method:}          &       MLE        & \textbf{  Df Model:          } &      420    \\
# \textbf{Date:}            & Fri, 01 May 2026 & \textbf{  Pseudo R-squ.:     } &   0.6662    \\
# \textbf{Time:}            &     17:38:59     & \textbf{  Log-Likelihood:    } &   -442.60   \\
# \textbf{converged:}       &       True       & \textbf{  LL-Null:           } &   -1325.8   \\
# \textbf{Covariance Type:} &       HC3        & \textbf{  LLR p-value:       } & 3.604e-164  \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
#                & \textbf{coef} & \textbf{std err} & \textbf{z} & \textbf{P$> |$z$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \textbf{const} &      -3.6877  &        0.286     &   -12.895  &         0.000        &       -4.248    &       -3.127     \\
# \textbf{x1}    &     -23.5639  &       24.584     &    -0.959  &         0.338        &      -71.747    &       24.619     \\
# \textbf{x2}    &      22.4844  &       24.329     &     0.924  &         0.355        &      -25.199    &       70.168     \\
# \textbf{x3}    &       3.4007  &        2.510     &     1.355  &         0.175        &       -1.519    &        8.320     \\
# \textbf{x4}    &     -37.1556  &       34.804     &    -1.068  &         0.286        &     -105.370    &       31.059     \\
# \textbf{x5}    &      21.4486  &       38.310     &     0.560  &         0.576        &      -53.637    &       96.534     \\
# \textbf{x6}    &      29.6769  &       38.148     &     0.778  &         0.437        &      -45.093    &      104.446     \\
# \textbf{x7}    &     -26.4833  &       17.087     &    -1.550  &         0.121        &      -59.974    &        7.008     \\
# \textbf{x8}    &      -0.5481  &        1.999     &    -0.274  &         0.784        &       -4.466    &        3.369     \\
# \textbf{x97}   &    -525.3329  &      174.920     &    -3.003  &         0.003        &     -868.169    &     -182.496     \\
# \textbf{x98}   &     -21.2477  &       58.949     &    -0.360  &         0.719        &     -136.785    &       94.289     \\
# \textbf{x99}   &      41.1107  &       31.232     &     1.316  &         0.188        &      -20.102    &      102.323     \\
# \textbf{x100}  &     -57.3701  &       31.589     &    -1.816  &         0.069        &     -119.283    &        4.543     \\
# \textbf{x101}  &      -5.3279  &        2.752     &    -1.936  &         0.053        &      -10.721    &        0.065     \\
# \textbf{x102}  &      31.3021  &       51.824     &     0.604  &         0.546        &      -70.270    &      132.874     \\
# \textbf{x103}  &      20.2920  &       54.996     &     0.369  &         0.712        &      -87.498    &      128.082     \\
# \textbf{x104}  &      72.7363  &       51.535     &     1.411  &         0.158        &      -28.271    &      173.743     \\
# \textbf{x105}  &      66.8365  &       31.440     &     2.126  &         0.034        &        5.216    &      128.457     \\
# \textbf{x106}  &       2.7554  &        1.496     &     1.842  &         0.065        &       -0.176    &        5.687     \\
# \textbf{x107}  &     110.0283  &       48.813     &     2.254  &         0.024        &       14.356    &      205.701     \\
# \textbf{x108}  &     910.4249  &      223.890     &     4.066  &         0.000        &      471.609    &     1349.241     \\
# \textbf{x109}  &    -247.9094  &       76.203     &    -3.253  &         0.001        &     -397.265    &      -98.554     \\
# \textbf{x110}  &      84.9108  &       65.260     &     1.301  &         0.193        &      -42.996    &      212.818     \\
# \textbf{x111}  &    -723.9217  &      192.486     &    -3.761  &         0.000        &    -1101.188    &     -346.656     \\
# \textbf{x112}  &     -75.4568  &       45.113     &    -1.673  &         0.094        &     -163.876    &       12.962     \\
# \textbf{x113}  &      87.8874  &       32.435     &     2.710  &         0.007        &       24.316    &      151.459     \\
# \textbf{x114}  &    -111.5032  &       33.064     &    -3.372  &         0.001        &     -176.308    &      -46.699     \\
# \textbf{x115}  &      -8.7826  &        2.759     &    -3.183  &         0.001        &      -14.190    &       -3.375     \\
# \textbf{x116}  &      46.3581  &       41.644     &     1.113  &         0.266        &      -35.263    &      127.979     \\
# \textbf{x117}  &     -35.5844  &       45.886     &    -0.775  &         0.438        &     -125.520    &       54.351     \\
# \textbf{x118}  &     115.1492  &       59.471     &     1.936  &         0.053        &       -1.411    &      231.709     \\
# \textbf{x119}  &      96.0425  &       32.892     &     2.920  &         0.004        &       31.576    &      160.509     \\
# \textbf{x120}  &       2.5641  &        1.453     &     1.765  &         0.078        &       -0.284    &        5.412     \\
# \textbf{x121}  &     136.8584  &       48.602     &     2.816  &         0.005        &       41.600    &      232.117     \\
# \textbf{x122}  &     892.6299  &      226.674     &     3.938  &         0.000        &      448.357    &     1336.903     \\
# \textbf{x123}  &    -266.3966  &       75.814     &    -3.514  &         0.000        &     -414.990    &     -117.804     \\
# \textbf{x124}  &     138.3239  &       66.784     &     2.071  &         0.038        &        7.430    &      269.218     \\
# \textbf{x125}  &    -922.3788  &      198.920     &    -4.637  &         0.000        &    -1312.254    &     -532.504     \\
# \textbf{x126}  &    -194.9920  &       56.887     &    -3.428  &         0.001        &     -306.488    &      -83.496     \\
# \textbf{x185}  &      -6.3481  &        3.158     &    -2.010  &         0.044        &      -12.538    &       -0.158     \\
# \textbf{x186}  &     -39.0845  &       48.330     &    -0.809  &         0.419        &     -133.809    &       55.640     \\
# \textbf{x187}  &     -96.1660  &       53.526     &    -1.797  &         0.072        &     -201.075    &        8.743     \\
# \textbf{x188}  &      29.4828  &       47.162     &     0.625  &         0.532        &      -62.953    &      121.918     \\
# \textbf{x189}  &     -53.9645  &       27.913     &    -1.933  &         0.053        &     -108.673    &        0.745     \\
# \textbf{x190}  &      -1.9010  &        1.656     &    -1.148  &         0.251        &       -5.147    &        1.345     \\
# \textbf{x191}  &    -127.8069  &       52.386     &    -2.440  &         0.015        &     -230.481    &      -25.133     \\
# \textbf{x192}  &     248.7415  &      232.089     &     1.072  &         0.284        &     -206.145    &      703.628     \\
# \textbf{x193}  &    -238.6751  &       70.662     &    -3.378  &         0.001        &     -377.171    &     -100.179     \\
# \textbf{x194}  &      75.2792  &       68.048     &     1.106  &         0.269        &      -58.093    &      208.651     \\
# \textbf{x195}  &    -175.3322  &      204.212     &    -0.859  &         0.391        &     -575.580    &      224.915     \\
# \textbf{x196}  &     -85.4118  &       43.673     &    -1.956  &         0.050        &     -171.009    &        0.186     \\
# \textbf{x197}  &     -65.4583  &       41.950     &    -1.560  &         0.119        &     -147.678    &       16.762     \\
# \textbf{x198}  &      54.2313  &       41.328     &     1.312  &         0.189        &      -26.769    &      135.232     \\
# \textbf{x199}  &      -8.6811  &        4.397     &    -1.975  &         0.048        &      -17.298    &       -0.064     \\
# \textbf{x200}  &     -47.3003  &       48.483     &    -0.976  &         0.329        &     -142.325    &       47.724     \\
# \textbf{x201}  &     -92.0451  &       46.289     &    -1.988  &         0.047        &     -182.770    &       -1.320     \\
# \textbf{x202}  &      42.0508  &       43.822     &     0.960  &         0.337        &      -43.839    &      127.941     \\
# \textbf{x203}  &    -108.3593  &       27.392     &    -3.956  &         0.000        &     -162.047    &      -54.671     \\
# \textbf{x204}  &      -3.9313  &        1.597     &    -2.461  &         0.014        &       -7.062    &       -0.801     \\
# \textbf{x205}  &    -133.6265  &       49.771     &    -2.685  &         0.007        &     -231.176    &      -36.077     \\
# \textbf{x206}  &     249.3780  &      231.765     &     1.076  &         0.282        &     -204.872    &      703.629     \\
# \textbf{x207}  &    -153.5480  &       68.860     &    -2.230  &         0.026        &     -288.511    &      -18.585     \\
# \textbf{x208}  &       9.4175  &       62.435     &     0.151  &         0.880        &     -112.952    &      131.787     \\
# \textbf{x209}  &     -66.2885  &      197.157     &    -0.336  &         0.737        &     -452.710    &      320.133     \\
# \textbf{x210}  &      22.6632  &       46.556     &     0.487  &         0.626        &      -68.584    &      113.911     \\
# \textbf{x211}  &    -102.5956  &       34.866     &    -2.943  &         0.003        &     -170.931    &      -34.260     \\
# \textbf{x212}  &      71.2143  &       35.226     &     2.022  &         0.043        &        2.172    &      140.257     \\
# \textbf{x213}  &      -4.2099  &        3.441     &    -1.223  &         0.221        &      -10.954    &        2.534     \\
# \textbf{x214}  &     -13.7873  &       58.907     &    -0.234  &         0.815        &     -129.243    &      101.668     \\
# \textbf{x215}  &     -97.9892  &       55.948     &    -1.751  &         0.080        &     -207.646    &       11.667     \\
# \textbf{x216}  &      84.9620  &       44.027     &     1.930  &         0.054        &       -1.330    &      171.254     \\
# \textbf{x217}  &     -74.2606  &       23.021     &    -3.226  &         0.001        &     -119.380    &      -29.141     \\
# \textbf{x218}  &      -2.4710  &        1.755     &    -1.408  &         0.159        &       -5.912    &        0.970     \\
# \textbf{x219}  &     -70.5439  &       47.574     &    -1.483  &         0.138        &     -163.788    &       22.700     \\
# \textbf{x220}  &     260.1760  &      226.355     &     1.149  &         0.250        &     -183.471    &      703.823     \\
# \textbf{x221}  &    -194.4889  &       68.600     &    -2.835  &         0.005        &     -328.942    &      -60.035     \\
# \textbf{x222}  &     -40.2347  &       64.894     &    -0.620  &         0.535        &     -167.424    &       86.955     \\
# \textbf{x223}  &     -56.1942  &      204.038     &    -0.275  &         0.783        &     -456.102    &      343.713     \\
# \textbf{x224}  &     -28.8223  &       48.365     &    -0.596  &         0.551        &     -123.616    &       65.972     \\
# \textbf{x225}  &     -74.7163  &       32.314     &    -2.312  &         0.021        &     -138.051    &      -11.382     \\
# \textbf{x226}  &      64.6019  &       33.069     &     1.954  &         0.051        &       -0.212    &      129.415     \\
# \textbf{x227}  &      -3.2867  &        3.962     &    -0.830  &         0.407        &      -11.051    &        4.478     \\
# \textbf{x228}  &     -46.9021  &       55.443     &    -0.846  &         0.398        &     -155.568    &       61.764     \\
# \textbf{x229}  &     -40.5876  &       51.970     &    -0.781  &         0.435        &     -142.446    &       61.271     \\
# \textbf{x230}  &      47.0328  &       48.891     &     0.962  &         0.336        &      -48.791    &      142.857     \\
# \textbf{x231}  &    -114.7986  &       26.530     &    -4.327  &         0.000        &     -166.797    &      -62.801     \\
# \textbf{x232}  &      -6.1015  &        1.777     &    -3.434  &         0.001        &       -9.584    &       -2.620     \\
# \textbf{x233}  &     -59.9507  &       44.914     &    -1.335  &         0.182        &     -147.980    &       28.079     \\
# \textbf{x234}  &     384.8733  &      218.680     &     1.760  &         0.078        &      -43.731    &      813.478     \\
# \textbf{x235}  &    -274.4541  &       70.804     &    -3.876  &         0.000        &     -413.227    &     -135.681     \\
# \textbf{x236}  &    -115.4675  &       62.030     &    -1.861  &         0.063        &     -237.045    &        6.110     \\
# \textbf{x237}  &     102.7603  &      207.337     &     0.496  &         0.620        &     -303.612    &      509.133     \\
# \textbf{x238}  &      23.7621  &       57.627     &     0.412  &         0.680        &      -89.184    &      136.709     \\
# \textbf{x239}  &     -65.2581  &       32.725     &    -1.994  &         0.046        &     -129.397    &       -1.119     \\
# \textbf{x240}  &      67.8882  &       33.846     &     2.006  &         0.045        &        1.551    &      134.226     \\
# \textbf{x241}  &      -4.4266  &        3.583     &    -1.235  &         0.217        &      -11.449    &        2.596     \\
# \textbf{x242}  &     -11.9038  &       52.885     &    -0.225  &         0.822        &     -115.556    &       91.748     \\
# \textbf{x243}  &     -53.9404  &       47.697     &    -1.131  &         0.258        &     -147.425    &       39.545     \\
# \textbf{x244}  &      21.5721  &       48.468     &     0.445  &         0.656        &      -73.423    &      116.567     \\
# \textbf{x245}  &     -99.8434  &       27.708     &    -3.603  &         0.000        &     -154.151    &      -45.536     \\
# \textbf{x246}  &      -2.4153  &        1.530     &    -1.579  &         0.114        &       -5.414    &        0.583     \\
# \textbf{x247}  &    -107.3550  &       46.007     &    -2.333  &         0.020        &     -197.528    &      -17.182     \\
# \textbf{x248}  &     273.7715  &      211.110     &     1.297  &         0.195        &     -139.997    &      687.540     \\
# \textbf{x249}  &    -270.9074  &       70.165     &    -3.861  &         0.000        &     -408.429    &     -133.386     \\
# \textbf{x250}  &    -156.4864  &       60.832     &    -2.572  &         0.010        &     -275.716    &      -37.257     \\
# \textbf{x251}  &      52.3565  &      194.885     &     0.269  &         0.788        &     -329.612    &      434.325     \\
# \textbf{x252}  &     -56.0483  &       46.017     &    -1.218  &         0.223        &     -146.239    &       34.143     \\
# \textbf{x253}  &     -44.0426  &       38.106     &    -1.156  &         0.248        &     -118.730    &       30.644     \\
# \textbf{x254}  &      75.5623  &       40.085     &     1.885  &         0.059        &       -3.003    &      154.127     \\
# \textbf{x255}  &      -2.7578  &        3.270     &    -0.843  &         0.399        &       -9.167    &        3.651     \\
# \textbf{x256}  &     -64.5054  &       44.534     &    -1.448  &         0.147        &     -151.791    &       22.780     \\
# \textbf{x257}  &       5.0056  &       41.387     &     0.121  &         0.904        &      -76.112    &       86.123     \\
# \textbf{x258}  &       8.8576  &       54.931     &     0.161  &         0.872        &      -98.806    &      116.521     \\
# \textbf{x259}  &    -106.2277  &       28.740     &    -3.696  &         0.000        &     -162.557    &      -49.899     \\
# \textbf{x260}  &      -3.8765  &        1.773     &    -2.187  &         0.029        &       -7.351    &       -0.402     \\
# \textbf{x261}  &     -67.7329  &       47.134     &    -1.437  &         0.151        &     -160.113    &       24.647     \\
# \textbf{x262}  &     304.5187  &      211.900     &     1.437  &         0.151        &     -110.798    &      719.836     \\
# \textbf{x263}  &    -347.2790  &       70.562     &    -4.922  &         0.000        &     -485.577    &     -208.981     \\
# \textbf{x264}  &    -184.5711  &       58.552     &    -3.152  &         0.002        &     -299.330    &      -69.812     \\
# \textbf{x265}  &     206.9049  &      188.213     &     1.099  &         0.272        &     -161.985    &      575.795     \\
# \textbf{x266}  &      58.2836  &       43.435     &     1.342  &         0.180        &      -26.848    &      143.415     \\
# \textbf{x267}  &      -9.3402  &       31.333     &    -0.298  &         0.766        &      -70.752    &       52.072     \\
# \textbf{x268}  &      30.8392  &       32.486     &     0.949  &         0.342        &      -32.832    &       94.511     \\
# \textbf{x269}  &      -1.6238  &        3.011     &    -0.539  &         0.590        &       -7.525    &        4.278     \\
# \textbf{x270}  &     -84.7887  &       46.645     &    -1.818  &         0.069        &     -176.212    &        6.634     \\
# \textbf{x271}  &      40.3469  &       44.054     &     0.916  &         0.360        &      -45.998    &      126.692     \\
# \textbf{x417}  &     -26.4427  &       33.644     &    -0.786  &         0.432        &      -92.384    &       39.498     \\
# \textbf{x418}  &      11.3386  &       27.763     &     0.408  &         0.683        &      -43.075    &       65.753     \\
# \textbf{x419}  &      34.8512  &       95.528     &     0.365  &         0.715        &     -152.381    &      222.083     \\
# \textbf{x420}  &       5.3784  &       49.321     &     0.109  &         0.913        &      -91.288    &      102.045     \\
# \bottomrule
# \end{tabular}
# %\caption{Logit Regression Results}
# \end{center}
#
# Possibly complete quasi-separation: A fraction 0.22 of observations can be \newline
#  perfectly predicted. This might indicate that there is complete \newline
#  quasi-separation. In this case some parameters will not be identified.

# %% [markdown]
# # SHAP

# %%
file_path = '/Users/vladislav/Desktop/Данные/predictions_for_1_days.xlsx'
data = pd.read_excel(file_path,index_col='TRADEDATE')
sifts = range(1,30)

for j in (data.drop('crisis',axis=1)).columns:
    data[j] = data[j].pct_change(fill_method=None)
data_copy = data.copy()
for sh in sifts:
    for j in (data_copy.drop('crisis',axis=1)).columns:
        data[f'{j}_lag_{sh}'] = data[j].shift(sh)
imputer = SimpleImputer(strategy='median')
train = data.iloc[:int(len(data)*0.6),:]
test = data.iloc[int(len(data)*0.6):,:]
x_train = train.drop('crisis',axis=1)
y_train = train['crisis']
x_test = test.drop('crisis',axis=1)
y_test = test['crisis']
x_train = imputer.fit_transform(x_train)
x_test = imputer.transform(x_test)

# %%
study = optuna.load_study(storage='sqlite:///xgboost_for_1day_study.db',study_name='xgboost_for_1day_study')
params = {'objective': 'binary:logistic',
        'eval_metric': 'auc',
          'seed': 42}
params.update(study.best_params)
scale_pos_weight = (
    (y_train == 0).sum() /
    (y_train == 1).sum()
)
dtrain = xgb.DMatrix(x_train, label=y_train)
dtest = xgb.DMatrix(x_test, label=y_test)
model_xgb = xgb.train(
    params,
    dtrain=dtrain,
    evals=[(dtrain,'train'),(dtest,'test')],
    num_boost_round=3000,
    early_stopping_rounds=100,
    verbose_eval=False
)
y_prob = model_xgb.predict(dtest)
threshold = 0.5
y_pred = (
    y_prob > threshold
).astype(int)

# %%
import shap
import matplotlib.pyplot as plt
import seaborn as sns
explainer = shap.TreeExplainer(model_xgb)
shap_values = explainer.shap_values(x_test)
mean_abs_shap = np.abs(shap_values).mean(axis=0)
global_shap_df = pd.DataFrame({
    'Feature': feature_names,
    'Mean_Abs_SHAP': mean_abs_shap,
    'Std_SHAP': np.abs(shap_values).std(axis=0)
}).sort_values('Mean_Abs_SHAP', ascending=False)
plt.figure(figsize=(14, 10))
sns.barplot(data=global_shap_df.head(40), x='Mean_Abs_SHAP', y='Feature', palette='viridis')
plt.title('SHAP: Глобальная важность признаков (ТОП-40)', fontsize=16, fontweight='bold')
plt.xlabel('Средний абсолютный SHAP value', fontsize=12)
plt.ylabel('Признак', fontsize=12)
plt.tight_layout()
plt.savefig('shap_values.png', dpi=300)
plt.show()
# Out:
# /var/folders/f5/kzrq0kqx07sb2j5ffctwkm4w0000gn/T/ipykernel_32761/2314062457.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=global_shap_df.head(40), x='Mean_Abs_SHAP', y='Feature', palette='viridis')
